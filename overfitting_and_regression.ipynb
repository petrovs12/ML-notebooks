# %%
# %load_ext autoreload
# %autoreload 2
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import ipywidgets as widgets
from utils import f,run_simulation

# %% [markdown]
# # set up a simple widget

# %%
widgets.interact(f, y=widgets.FloatSlider(min=1, max=10, step=0.1, value=10, description='y'))
# Out:
# interactive(children=(FloatSlider(value=10.0, description='y', max=10.0, min=1.0), Output()), _dom_classes=('w…
# <function utils.f(y)>

# %%
# Assuming run_simulation returns a DataFrame with columns 'degree', 'train_rmse', and 'test_rmse'
df = run_simulation()
print(df)
# Plotting train_rmse and test_rmse against degree
plt.figure(figsize=(10, 6))
plt.plot(df['degree'], df['train_rmse'], label='Train RMSE', marker='o')
plt.plot(df['degree'], df['test_rmse'], label='Test RMSE', marker='o')
plt.xlabel('Degree')
plt.ylabel('RMSE')
plt.title('Train and Test RMSE vs Degree')
plt.legend()
plt.grid(True)
plt.show()
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:                      y   R-squared:                      -0.000
# Model:                            OLS   Adj. R-squared:                 -0.000
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Mon, 16 Dec 2024   Prob (F-statistic):                nan
# Time:                        20:53:44   Log-Likelihood:                -209.82
# No. Observations:                 200   AIC:                             421.6
# Df Residuals:                     199   BIC:                             424.9
# Df Model:                           0
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0027      0.049      0.056      0.956      -0.094       0.099
# ...
