# %%
# !pip install 'stable-baselines3[extra]'
# Out:
# Collecting stable-baselines3[extra]
#   Downloading stable_baselines3-2.4.0-py3-none-any.whl.metadata (4.5 kB)
# Collecting gymnasium<1.1.0,>=0.29.1 (from stable-baselines3[extra])
#   Downloading gymnasium-1.0.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: numpy<2.0,>=1.20 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (1.26.4)
# Requirement already satisfied: torch>=1.13 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.3.1.post100)
# Collecting cloudpickle (from stable-baselines3[extra])
#   Downloading cloudpickle-3.1.0-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: pandas in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (2.2.3)
# Requirement already satisfied: matplotlib in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (3.9.2)
# Collecting opencv-python (from stable-baselines3[extra])
#   Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting pygame (from stable-baselines3[extra])
#   Downloading pygame-2.6.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting tensorboard>=2.9.1 (from stable-baselines3[extra])
#   Downloading tensorboard-2.18.0-py3-none-any.whl.metadata (1.6 kB)
# Requirement already satisfied: psutil in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (5.9.0)
# Requirement already satisfied: tqdm in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (4.67.1)
# Requirement already satisfied: rich in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (13.9.4)
# Collecting ale-py>=0.9.0 (from stable-baselines3[extra])
#   Downloading ale_py-0.10.1-cp312-cp312-macosx_11_0_arm64.whl.metadata (7.6 kB)
# Requirement already satisfied: pillow in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from stable-baselines3[extra]) (11.0.0)
# Requirement already satisfied: typing-extensions>=4.3.0 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra]) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium<1.1.0,>=0.29.1->stable-baselines3[extra])
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Collecting absl-py>=0.4 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading absl_py-2.1.0-py3-none-any.whl.metadata (2.3 kB)
# Collecting grpcio>=1.48.2 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading grpcio-1.68.1-cp312-cp312-macosx_10_9_universal2.whl.metadata (3.9 kB)
# Collecting markdown>=2.6.8 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Using cached Markdown-3.7-py3-none-any.whl.metadata (7.0 kB)
# Requirement already satisfied: packaging in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (24.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (5.29.2)
# Requirement already satisfied: setuptools>=41.0.0 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (72.1.0)
# Requirement already satisfied: six>1.9 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]) (1.17.0)
# Collecting tensorboard-data-server<0.8.0,>=0.7.0 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading tensorboard_data_server-0.7.2-py3-none-any.whl.metadata (1.1 kB)
# Collecting werkzeug>=1.0.1 (from tensorboard>=2.9.1->stable-baselines3[extra])
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: filelock in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.13.1)
# Requirement already satisfied: sympy in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (1.13.2)
# Requirement already satisfied: networkx in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.3)
# Requirement already satisfied: jinja2 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (3.1.4)
# Requirement already satisfied: fsspec in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from torch>=1.13->stable-baselines3[extra]) (2024.6.1)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from matplotlib->stable-baselines3[extra]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from pandas->stable-baselines3[extra]) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from pandas->stable-baselines3[extra]) (2023.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from rich->stable-baselines3[extra]) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from rich->stable-baselines3[extra]) (2.18.0)
# Requirement already satisfied: mdurl~=0.1 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich->stable-baselines3[extra]) (0.1.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]) (2.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages (from sympy->torch>=1.13->stable-baselines3[extra]) (1.3.0)
# Downloading ale_py-0.10.1-cp312-cp312-macosx_11_0_arm64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 12.3 MB/s eta 0:00:00
# Downloading gymnasium-1.0.0-py3-none-any.whl (958 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 958.1/958.1 kB 12.2 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.0-py3-none-any.whl (22 kB)
# Downloading tensorboard-2.18.0-py3-none-any.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 8.9 MB/s eta 0:00:00ta 0:00:01
# Downloading opencv_python-4.10.0.84-cp37-abi3-macosx_11_0_arm64.whl (54.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.8/54.8 MB 10.3 MB/s eta 0:00:00a 0:00:01
# Downloading pygame-2.6.1-cp312-cp312-macosx_11_0_arm64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 11.4 MB/s eta 0:00:00a 0:00:01
# Downloading stable_baselines3-2.4.0-py3-none-any.whl (183 kB)
# Downloading absl_py-2.1.0-py3-none-any.whl (133 kB)
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Downloading grpcio-1.68.1-cp312-cp312-macosx_10_9_universal2.whl (11.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.1/11.1 MB 11.7 MB/s eta 0:00:00a 0:00:01
# Using cached Markdown-3.7-py3-none-any.whl (106 kB)
# Downloading tensorboard_data_server-0.7.2-py3-none-any.whl (2.4 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Installing collected packages: farama-notifications, werkzeug, tensorboard-data-server, pygame, opencv-python, markdown, grpcio, cloudpickle, ale-py, absl-py, tensorboard, gymnasium, stable-baselines3
# Successfully installed absl-py-2.1.0 ale-py-0.10.1 cloudpickle-3.1.0 farama-notifications-0.0.4 grpcio-1.68.1 gymnasium-1.0.0 markdown-3.7 opencv-python-4.10.0.84 pygame-2.6.1 stable-baselines3-2.4.0 tensorboard-2.18.0 tensorboard-data-server-0.7.2 werkzeug-3.1.3

# %%
import gymnasium as gym

from stable_baselines3 import PPO

env = gym.make("CartPole-v1", render_mode="human")

model = PPO("MlpPolicy", env, verbose=1,device = "mps")
model.learn(total_timesteps=10_000)

vec_env = model.get_env()
obs = vec_env.reset()
for i in range(1000):
    action, _states = model.predict(obs, deterministic=True)
    obs, reward, done, info = vec_env.step(action)
    vec_env.render()
    if i%100 == 0:
        print(f"Step {i}, Reward: {reward}, action: {action}")
    # VecEnv resets automatically
    # if done:
    #   obs = env.reset()

env.close()
# Out:
# Using mps device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# /opt/homebrew/anaconda3/envs/ml-tutorials/lib/python3.12/site-packages/stable_baselines3/common/on_policy_algorithm.py:150: UserWarning: You are trying to run PPO on the GPU, but it is primarily intended to run on the CPU when not using a CNN policy (you are using ActorCriticPolicy which should be a MlpPolicy). See https://github.com/DLR-RM/stable-baselines3/issues/1245 for more info. You can pass `device='cpu'` or `export CUDA_VISIBLE_DEVICES=` to force using the CPU.Note: The model will train, but the GPU utilization will be poor and the training might take longer than on CPU.
#   warnings.warn(
# 2024-12-21 14:21:53.402 python[16237:7344130] +[IMKClient subclass]: chose IMKClient_Modern
# 2024-12-21 14:21:53.402 python[16237:7344130] +[IMKInputSession subclass]: chose IMKInputSession_Modern
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 21.7     |
# |    ep_rew_mean     | 21.7     |
# | time/              |          |
# |    fps             | 0        |
# |    iterations      | 1        |
# |    time_elapsed    | 3607     |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 27.1        |
# |    ep_rew_mean          | 27.1        |
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 2           |
# |    time_elapsed         | 9808        |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008053927 |
# |    clip_fraction        | 0.0991      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | -0.00525    |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.1         |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0151     |
# |    value_loss           | 51.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 36          |
# |    ep_rew_mean          | 36          |
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 3           |
# |    time_elapsed         | 10747       |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009820063 |
# |    clip_fraction        | 0.0699      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.661      |
# |    explained_variance   | 0.0881      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 12.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0193     |
# |    value_loss           | 33.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 47.4        |
# |    ep_rew_mean          | 47.4        |
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 4           |
# |    time_elapsed         | 10797       |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.010807739 |
# |    clip_fraction        | 0.0863      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.636      |
# |    explained_variance   | 0.297       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 20.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0201     |
# |    value_loss           | 48.3        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 62.7        |
# |    ep_rew_mean          | 62.7        |
# | time/                   |             |
# |    fps                  | 0           |
# |    iterations           | 5           |
# |    time_elapsed         | 10845       |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.006969816 |
# |    clip_fraction        | 0.052       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.604      |
# |    explained_variance   | 0.23        |
# |    learning_rate        | 0.0003      |
# |    loss                 | 22.7        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0137     |
# |    value_loss           | 72.5        |
# -----------------------------------------
# Step 0, Reward: [1.], action: [0]
# Step 100, Reward: [1.], action: [1]
# Step 200, Reward: [1.], action: [1]
# Step 300, Reward: [1.], action: [0]
# Step 400, Reward: [1.], action: [0]
# Step 500, Reward: [1.], action: [1]
# Step 600, Reward: [1.], action: [1]
# Step 700, Reward: [1.], action: [0]
# Step 800, Reward: [1.], action: [0]
# Step 900, Reward: [1.], action: [0]
